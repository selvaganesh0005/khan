# %%
# Import libraries
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DateType
from pyspark.sql.functions import current_date

# Spark session (already available in Databricks)
spark = SparkSession.builder.getOrCreate()

# Sample data
data = [
    (1, "Alice", "Engineering", 75000, "2024-01-15"),
    (2, "Bob", "Marketing", 55000, "2024-02-20"),
    (3, "Charlie", "Engineering", 80000, "2024-03-10"),
    (4, "Diana", "HR", 60000, "2024-04-05"),
    (5, "Eve", "Marketing", 52000, "2024-05-18")
]

# Define schema
schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("department", StringType(), True),
    StructField("salary", IntegerType(), True),
    StructField("join_date", StringType(), True)
])

# Create DataFrame
df = spark.createDataFrame(data, schema)

# Show DataFrame
df.show()

# %%
# Method 1: Save as a new table
df.write \
  .format("delta") \
  .mode("overwrite") \
  .saveAsTable("devkhan.bronze.employees")

print("Table created successfully!")
